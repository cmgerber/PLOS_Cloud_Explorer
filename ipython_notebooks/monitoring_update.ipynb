# %%
import pandas as pd
import numpy as np 
import os

# %%
pd.read_pickle('../data/pickles/plos_pickle_0.pkl')
# Out:
#                                              abstract  \
# 0   [\nClenbuterol, a β2-agonist, induces skeletal...
# 1   [\nRecent studies point to an association betw...
# 2   [\nThe reduction of game and fish populations ...
# 3   [Background: Cebu has been one of the most lep...
# 4   [Background: Understanding how androgen recept...
# 5   [\n        Rapid development of nanotechnologi...
# 6   [\nIdentifying natural allelic variation that ...
# 7   [We uncovered the underlying energy landscape ...
# 8   [\n        A novel porcine pathogen tentativel...
# 9   [Background: Alterations in the stem cell nich...
# 10  [\n        Congenital hydrocephalus (CH) is a ...
# 11  [\nIn spite of extensive research, the mechani...
# 12  [\n        Acetylcholinesterase (AChE) inhibit...
# 13  [\nThe role of mutation rate in optimizing key...
# 14  [\n        Nasal carriage of Staphylococcus au...
# 15  [Background: Hepatitis E Virus (HEV) infection...
# ...
