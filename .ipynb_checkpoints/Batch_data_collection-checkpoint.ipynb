# %% [markdown]
# ## Batch Data Collection

# %% [markdown]
# This notebook will download all 100k+ articles with abstracts from the PLOS api.
#
# nbviewer to share: http://nbviewer.ipython.org/gist/anonymous/11133500

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import settings
import requests
import urllib
import time

# %% [markdown]
# ### API Call Function

# %%
#adapted from Raymond's notebook

def plos_search(q,start=0,rows=100,fl=None, extras=None):

    BASE_URL = 'http://api.plos.org/search'
    DEFAULT_FL = ('abstract','author',
                  'id','journal','publication_date',
                  'score','title_display', 'subject','subject_level')
        #removed elements: eissn, article_type
    
    # fl indicates fields to return
    # http://wiki.apache.org/solr/CommonQueryParameters#fl
    
    if fl is None:
        fl_ = ",".join(DEFAULT_FL)
    else:
        fl_ = ",".join(fl)
        
    query = {'q':q,
             'start':start,
             'rows':rows,
             'api_key':settings.PLOS_KEY,
             'wt':'json',
             'fl':fl_,
             'fq': 'doc_type:full AND !article_type_facet:"Issue Image"'}
    
    if extras is not None:
        query.update(extras)
        
    query_url = BASE_URL + "?" +urllib.urlencode(query)
    
    r = requests.get(query_url)
    return r

# %% [markdown]
# ### Finding Parameters

# %% [markdown]
# Need to make sure the calls do not exceed the following:
#
# 7200 requests a day, 300 per hour, 10 per minute and allow 5 seconds for your search to return results.
#
# To be safe there will be a 15 second wait between each call:
# 15 sec per call
# 4 calls per minute
# 240 calls per hour

# %% [markdown]
# Call for all articles

# %%
r = plos_search(q="*:*")

# %% [markdown]
# Check the total number of articles with abstracts.

# %%
tot_articles = r.json()['response']['numFound']
tot_articles
# Out:
# 118545

# %% [markdown]
# With 118545 acticles total that means that we will have to perform 1,186 API requests at 100 articles per request.
#
# At 240 requests per hour it should take about 5 hours to get all the data needed.

# %% [markdown]
# ### Looping Function

# %% [markdown]
# This function will call the plos_search function every 15 seconds while incrementing the start number so that all of the articles can be pulled.

# %%
def data_request(end, start=0):
    loops = (end/100) + 1
    for n in range(loops):
        r = plos_search(q="*:*", start=start)
        
        #store data before next call
        data = r.json()['response']['docs']
        if start == 0:
            abstract_df = pd.DataFrame(data)
        else:
            abstract_df = abstract_df.append(pd.DataFrame(data))
        
        #increment the start for the next request
        start+=100
        
        #every 10000 articles pickle the dataframe
        if (start%10000)==0:
            abstract_df.to_pickle('abstract_df.pkl')
            print start
        
        #wait 15 seconds before the next loop
        time.sleep(15)
        
    #pickle when finished
    abstract_df.to_pickle('abstract_df.pkl')
    
    return abstract_df

# %% [markdown]
# Now we can run the function inputing the tot_articles as the end parameter.

# %%
abstract_df = data_request(end=200)

# %% [markdown]
# ### Exploring Output

# %%
abstract_df.columns
# Out:
# Index([u'abstract', u'author', u'id', u'journal', u'publication_date', u'score', u'subject', u'title_display'], dtype='object')

# %%
print list(abstract_df.subject)[0]
# Out:
# [u'/Biology and life sciences/Developmental biology/Molecular development/Cytokines', u'/Medicine and health sciences/Surgical and invasive medical procedures/Electrical stimulation', u'/Biology and life sciences/Physiology/Immune physiology/Cytokines', u'/Biology and life sciences/Immunology/Immune system/Innate immune system/Cytokines', u'/Medicine and health sciences/Immunology/Immune response/Inflammation', u'/Biology and life sciences/Physiology/Body fluids/Blood/Blood plasma', u'/Medicine and health sciences/Immunology/Immune system/Innate immune system/Cytokines', u'/Biology and life sciences/Immunology/Immune response/Inflammation', u'/Medicine and health sciences/Physiology/Body fluids/Blood/Blood plasma', u'/Medicine and health sciences/Physiology/Physiological processes/Respiration/Breathing', u'/Medicine and health sciences/Anatomy/Body fluids/Blood/Blood plasma', u'/Biology and life sciences/Physiology/Physiological processes/Respiration/Breathing', u'/Medicine and health sciences/Hematology/Blood/Blood plasma', u'/Medicine and health sciences/Surgical and invasive medical procedures/Nervous system procedures/Vagotomy', u'/Medicine and health sciences/Pathology and laboratory medicine/Signs and symptoms/Inflammation', u'/Medicine and health sciences/Physiology/Immune physiology/Cytokines', u'/Medicine and health sciences/Pathology and laboratory medicine/Signs and symptoms/Sepsis/Systemic inflammatory response syndrome', u'/Biology and life sciences/Anatomy/Body fluids/Blood/Blood plasma', u'/Medicine and health sciences/Pulmonology/Pulmonary function/Tidal volume']

# %%
abstract_df
# Out:
#                                              abstract  \
# 0   [\n        Pulmonary inflammation contributes ...
# 1   [\nWe investigated the diurnal oscillation in ...
# 2   [Background: Alveolar echinococcosis (AE) is a...
# 3   [\n        Recently we proposed exploring the ...
# 4   [\nChagas disease, caused by the protozoan par...
# 5   [\nSome ubiquitin-like (UBL) domain-containing...
# 6   [Background: Giardia duodenalis is highly ende...
# 7   [Background: To explain observed differences d...
# 8   [Background: Mammalian cardiac myocytes withdr...
# 9   [\n        The diversity, ubiquity and prevale...
# 10  [Background: A combination of clinical and rou...
# 11  [: Ben Scheres and colleagues report that in t...
# 12  [Background: PDZK1 is a four PDZ-domain contai...
# 13  [\n\t\t\t\tHydropericardium-hepatitis syndrome...
# 14  [\nIt has long been observed that tamoxifen se...
# 15  [\nOur prior research has shown that environme...
# 16  [Background: Bluetongue (BT) is a vector-borne...
# 17  [Calorie restriction (CR), the only non-geneti...
# 18  [: The GAL cluster-associated long non-coding ...
# 19  [\nThe formation and maintenance of cell-cell ...
# 20  [\n        Hepatocellular carcinoma is one of ...
# 21  [Background: To assess the relationship betwee...
# 22  [\nThe objective of this study was to determin...
# 23  [Background: Published estimates on age-depend...
# 24  [\nBrown adipose tissue has gained interest as...
# 25  [\n        Adenoviral replication depends on v...
# 26  [\n11β-hydroxysteroid dehydrogenase type 1 (11...
# 27  [\n        Deregulation of the transforming gr...
# 28  [Circadian clocks organize the precise timing ...
# 29  [\nSocial structure is proposed to influence t...
# 30  [DNA methylation directed by 24-nucleotide sma...
# 31  [Objectives: We study the applicability of a v...
# 32  [Background: Miniature inverted-repeat transpo...
# 33  [\nSustaining life beyond Earth either on spac...
# 34  [Background: This study elucidates exposure-re...
# 35  [\n\t\t\t\tSoy (Glycine Max Merr, family Legum...
# 36  [: Dietary exposures implicated as reducing or...
# 37  [Background: Vitamin B12 deficiency is prevale...
# 38  [Background: Programmed death ligand-1 (PD-L1)...
# 39  [\nWe asked whether and how a sequence of a ho...
# 40  [Background: Head and neck squamous cell carci...
# 41  [\n        Clinical data suggest that progesti...
# 42  [\n\t\t\t\tIonic liquids (ILs) are room-temper...
# 43  [\n        Biodiversity conservation and ecosy...
# 44  [\n        Coronary atherosclerosis, the main ...
# 45  [\n        Invasive cancer causes a change in ...
# 46  [\nThe model filamentous fungus Neurospora cra...
# 47  [: The Myxococcus Agl-Nfs machinery, a type of...
# 48  [\nInstitutional care is a growing component o...
# 49                                                 []
# 50  [\nIn the process of mate selection by female ...
# 51  [\n        Ploidy varies tremendously within a...
# 52  [Background: The mechanisms of disease severit...
# 53  [\nThe scavenger receptor CD36 plays important...
# 54                                                 []
# 55  [\nDisseminated tumor cells (DTCs) are believe...
# 56  [\nLymphatic vessels are derived from venous e...
# 57  [Background: Several studies have reported imp...
# 58  [\n        The Notch signaling pathway is esse...
# 59  [\n        Recently, BRCA1 germline mutations ...
#                                                   ...
#
#                                                author  \
# 0   [Matthijs Kox, Michiel Vaneker, Johannes G van...
# 1     [Milena Damulewicz, Ezio Rosato, Elzbieta Pyza]
# 2   [Renyong Lin, Guodong Lü, Junhua Wang, Chuansh...
# 3   [Alice L den Hertog, Alex F de Vos, Paul R Kla...
# 4   [Cristina Sanoja, Sofía Carbajosa, Manuel Fres...
# 5   [Hyunjeong Yang, Hiroshi Takagi, Yoshiyuki Kon...
# 6   [Ralf Ignatius, Jean Bosco Gahutu, Christian K...
# 7   [Céline Couteau, Catherine Chauvet, Eva Papari...
# 8   [Carmen H Coxon, Katrina A Bicknell, Fleur L M...
# 9   [Eric Pante, Scott C France, Arnaud Couloux, C...
# 10  [Josep Lupón, Marta de Antonio, Joan Vila, Jud...
# 11  [Alfredo Cruz-Ramírez, Sara Díaz-Triviño, Guy ...
# 12  [Kosuke Tsukamoto, Lorenna Buck, Walker Inman,...
# 13  [Helena Grgić, Zvonimir Poljak, Shayan Sharif,...
# 14  [Liming Weng, Dana Ziliak, Bonnie LaCroix, Pau...
# 15  [Xiuzhen Fan, Dingge Li, Cheryl F Lichti, Thom...
# 16  [Rodrigo García-Lastra, Iratxe Leginagoikoa, J...
# 17  [Min Wei, Paola Fabrizio, Jia Hu, Huanying Ge,...
# 18  [Sara C Cloutier, Siwen Wang, Wai Kit Ma, Chri...
# 19  [Jae-Joon Jung, Shivangi M Inamdar, Ajit Tiwar...
# 20  [Kazuaki Nakamura, Kazuko Aizawa, Kazuhiko Nak...
# 21  [Lorenzo Moja, Alessandra Piatti, Valentina Pe...
# 22             [Vaibhav Mundra, Hao Wu, Ram I Mahato]
# 23  [Nicole Scheuing, Reinhard W Holl, Gerd Dockte...
# 24  [Silja Raschke, Manuela Elsen, Hans Gassenhube...
# 25  [Wilhelm Ching, Emre Koyuncu, Sonia Singh, Chr...
# 12  10.1371/journal.pone.0069725                          PLoS ONE
# 13  10.1371/journal.pone.0077601                          PLoS ONE
# 14  10.1371/journal.pone.0093420                          PLoS ONE
# 15  10.1371/journal.pone.0073689                          PLoS ONE
# 16  10.1371/journal.pone.0034421                          PLoS ONE
# 17  10.1371/journal.pgen.0040013                     PLoS Genetics
# 18  10.1371/journal.pbio.1001715                      PLoS Biology
# 19  10.1371/journal.pone.0061857                          PLoS ONE
# 20  10.1371/journal.pone.0054036                          PLoS ONE
# 21  10.1371/journal.pone.0046175                               NaN
# 22  10.1371/journal.pone.0077591                          PLoS ONE
# 23  10.1371/journal.pone.0081545                          PLoS ONE
# 24  10.1371/journal.pone.0073680                          PLoS ONE
# 25  10.1371/journal.ppat.1003273                    PLoS Pathogens
# 26  10.1371/journal.pone.0089421                          PLoS ONE
# 27  10.1371/journal.pone.0022606                          PLoS ONE
# 28  10.1371/journal.pgen.0040012                     PLoS Genetics
# 29  10.1371/journal.pone.0093408                          PLoS ONE
# 30  10.1371/journal.pgen.0040027                     PLoS Genetics
# 31  10.1371/journal.pone.0073691                          PLoS ONE
# 32  10.1371/journal.pone.0010700                          PLoS ONE
# 33  10.1371/journal.pone.0006753                          PLoS ONE
# 34  10.1371/journal.pone.0038359                          PLoS ONE
# 35  10.1371/journal.pone.0081556                          PLoS ONE
# 36  10.1371/journal.pone.0018707                          PLoS ONE
# 37  10.1371/journal.pone.0057998                          PLoS ONE
# 38  10.1371/journal.pone.0065821                          PLoS ONE
# 39  10.1371/journal.pone.0002810                          PLoS ONE
# 40  10.1371/journal.pone.0014558                          PLoS ONE
# 41  10.1371/journal.pone.0022620                          PLoS ONE
# 42  10.1371/journal.pone.0085467                          PLoS ONE
# 43  10.1371/journal.pone.0030506                          PLoS ONE
# 44  10.1371/journal.pone.0042283                               NaN
# 45  10.1371/journal.pone.0054047                          PLoS ONE
# 46  10.1371/journal.pone.0010703                          PLoS ONE
# 47  10.1371/journal.pbio.1001728                      PLoS Biology
# 48  10.1371/journal.pone.0069728                          PLoS ONE
# 49  10.1371/journal.ppat.1003288                    PLoS Pathogens
# 50  10.1371/journal.pone.0089438                          PLoS ONE
# 51  10.1371/journal.pone.0026599                          PLoS ONE
# 52  10.1371/journal.pone.0014561                          PLoS ONE
# 53  10.1371/journal.pone.0077604                          PLoS ONE
# 54  10.1371/journal.pmed.0010023                     PLoS Medicine
# 55  10.1371/journal.pone.0061873                          PLoS ONE
# 56  10.1371/journal.pone.0073693                          PLoS ONE
# 57  10.1371/journal.pone.0010702                          PLoS ONE
# 58  10.1371/journal.pone.0018709                          PLoS ONE
# 59  10.1371/journal.pone.0038361                          PLoS ONE
#                              ...                               ...
#
#         publication_date  score  \
# 0   2012-04-06T00:00:00Z      1
# 1   2013-09-10T00:00:00Z      1
# 2   2011-01-19T00:00:00Z      1
# 3   2013-02-28T00:00:00Z      1
# 4   2013-06-11T00:00:00Z      1
# 9   Deep-Sea Origin and In-Situ Diversification of...
# 10  Development of a Novel Heart Failure Risk Tool...
# 11  A SCARECROW-RETINOBLASTOMA Protein Network Con...
# 12  Challenges in Using Cultured Primary Rodent He...
# 13  Pathogenicity and Cytokine Gene Expression Pat...
# 14  Integrative “Omic” Analysis for Tamoxifen Sens...
# 15  Dynamic Proteomics of Nucleus Accumbens in Res...
# 16  Bluetongue Virus Serotype 1 Outbreak in the Ba...
# 17  Life Span Extension by Calorie Restriction Dep...
# 18  Long Noncoding RNAs Promote Transcriptional Po...
# 19  Syntaxin 16 Regulates Lumen Formation during E...
# 20  DNA Methyltransferase Inhibitor Zebularine Inh...
# 21  Timing Matters in Hip Fracture Surgery: Patien...
# 22  Genetically Modified Human Bone Marrow Derived...
# 23  Diabetes in Cystic Fibrosis: Multicenter Scree...
# 24  Evidence against a Beneficial Effect of Irisin...
# 25  A Ubiquitin-specific Protease Possesses a Deci...
# 26  Regulation of 11β-Hydroxysteroid Dehydrogenase...
# 27  ChIP-seq Defined Genome-Wide Map of TGFβ/SMAD4...
# 28  Dominant-Negative CK2α Induces Potent Effects ...
# 29  The Influence of Social Structure, Habitat, an...
# 30  Dynamic Regulation of ARGONAUTE4 within Multip...
# 31  A Comparison of Two Spelling Brain-Computer In...
# 32  Characterization of a Group of MITEs with Unus...
# 33  Detrimental Effects of Microgravity on Mouse P...
# 34  Performance of Repetitive Tasks Induces Decrea...
# 35  Soyasaponin I Improved Neuroprotection and Reg...
# 36  Inhibition of Fried Meat-Induced Colorectal DN...
# 37  Low Vitamin B12 Levels among Newly-Arrived Ref...
# 38  PTEN Loss Increases PD-L1 Protein Expression a...
# 39  Does an Insect's Unconditioned Response to Suc...
# 40  Transient Alteration of Cellular Redox Bufferi...
# 41  Intestinal Tumorigenesis Is Not Affected by Pr...
# 42  The Effect of Hydrophilic Ionic Liquids 1-Ethy...
# 43  Predicting Tropical Dry Forest Successional At...
# 44  Cross-Reacting Antibacterial Auto-Antibodies A...
# 45  Imaging of Metastatic Lymph Nodes by X-ray Pha...
# 46  Characterization of the Temperature-Sensitive ...
# 47  A Versatile Class of Cell Surface Directional ...
# 48  Unit Cost of Medical Services at Different Hos...
# 49  A Disconnect between the Neurospirochetoses in...
# 50  Mate Choice in Adult Female Bengalese Finches:...
# 51  Cryptic Fitness Advantage: Diploids Invade Hap...
# 52  Increased Inducible Nitric Oxide Synthase Expr...
# 53  CD36 Contributes to Malaria Parasite-Induced P...
# 54                 Oats Intolerance in Celiac Disease
# 55  GAS6 Receptor Status Is Associated with Dorman...
# 56  Atypical E2fs Control Lymphangiogenesis throug...
# 57  Statin Treatment and Mortality in Bacterial In...
# 58  Gamma-Secretase Inhibitor Treatment Promotes V...
# 59  <i>BRCA2</i> Mutations and Triple-Negative Bre...
#                                                   ...
#
# [300 rows x 8 columns]

# %% [markdown]
# ### Cleaning Output

# %%
118545/100
# Out:
# 1185
